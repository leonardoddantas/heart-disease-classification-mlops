# %%
import wandb

wandb.init(
    project="heart-disease-classification-mlops",
    job_type="load_raw",
    name="mlops-baseline"
)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from C:\Users\leona\_netrc.
# wandb: Currently logged in as: leonardo-dantas-120 (tomazfil-team) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>c:\Users\leona\Downloads\heart-disease-classification-mlops\notebooks\wandb\run-20260428_213209-hf8jfnkg</code>
# Syncing run <strong><a href='https://wandb.ai/tomazfil-team/heart-disease-classification-mlops/runs/hf8jfnkg' target="_blank">mlops-baseline</a></strong> to <a href='https://wandb.ai/tomazfil-team/heart-disease-classification-mlops' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tomazfil-team/heart-disease-classification-mlops' target="_blank">https://wandb.ai/tomazfil-team/heart-disease-classification-mlops</a>
# ...
